# %%
import pandas as pd

# %%
import seaborn as sns

# %%
dados = pd.read_csv(r'C:\Users\BSSRIO_DIR\Documents\Olimpiadas.csv')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269718 entries, 0 to 269717
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ano          269718 non-null  int64
#  1   edicao       269718 non-null  object
#  2   cidade_sede  269718 non-null  object
#  3   pais         269348 non-null  object
#  4   delegacao    269718 non-null  object
#  5   equipe       269718 non-null  object
#  6   id_atleta    269718 non-null  int64
#  7   nome_atleta  269718 non-null  object
#  8   sexo         269718 non-null  object
#  9   idade        260410 non-null  float64
#  10  altura       210917 non-null  float64
#  11  peso         208204 non-null  float64
#  12  esporte      269718 non-null  object
#  13  evento       269718 non-null  object
#  14  medalha      39772 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 30.9+ MB

# %%
rio = dados['cidade_sede'] == 'Rio de Janeiro'

# %%
RJ = dados[rio]

# %%
RJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13688 entries, 256030 to 269717
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ano          13688 non-null  int64
#  1   edicao       13688 non-null  object
#  2   cidade_sede  13688 non-null  object
#  3   pais         13643 non-null  object
#  4   delegacao    13688 non-null  object
#  5   equipe       13688 non-null  object
#  6   id_atleta    13688 non-null  int64
#  7   nome_atleta  13688 non-null  object
#  8   sexo         13688 non-null  object
#  9   idade        13688 non-null  float64
#  10  altura       13512 non-null  float64
#  11  peso         13465 non-null  float64
#  12  esporte      13688 non-null  object
#  13  evento       13688 non-null  object
#  14  medalha      2023 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.7+ MB

# %%
sns.pairplot(RJ, hue='esporte', vars=['peso', 'altura', 'idade', 'ano'])

# %%
sns.pairplot(RJ, hue='esporte')

# %%
sns.pairplot(RJ, hue='esporte', vars=['peso','altura'])

# %%
RJ['medalha'].hist()
# Out:
# <AxesSubplot:>

# %%
filtro1 = RJ['esporte'] == 'Gymnastics'

# %%
gym = RJ[filtro1]

# %%
gym['peso'].hist()
# Out:
# <AxesSubplot:>

# %%
filtro2 = RJ['esporte'] == 'Handball'

# %%
hnd = RJ[filtro2]

# %%
hnd['peso'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(RJ, hue='sexo', x_vars=['peso'], y_vars=['altura'])

# %%
sns.pairplot(RJ, hue='esporte', x_vars=['idade'], y_vars=['altura'])

# %%
RJ.hist('idade')
# Out:
# array([[<AxesSubplot:title={'center':'idade'}>]], dtype=object)

# %%
fig = sns.displot(RJ, x = "idade", hue = "esporte")

# %%
filtro3 = RJ['esporte'] == 'Equestrianism'

# %%
equ = RJ[filtro3]

# %%
fig = sns.displot(equ, x = "idade", hue = "esporte")

# %%
fig = sns.displot(gym, x = "idade", hue = "esporte")

# %%
fig = sns.displot(med, x = "medalha", hue = "delegacao")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 fig = sns.displot(med, x = "medalha", hue = "delegacao")
#
# NameError: name 'med' is not defined

# %%
def classfificacao(medalha):
     if medalha == 'Gold':
        return 1
    elif medalha == 'Silver':
        return 2
    elif valor == 'Bronze':
        return 3

# %%
filtro4 = RJ['medalha'] == 'Gold'

# %%
med = RJ[filtro4]

# %%
sns.distplot(RJ['altura'], label='altura')
sns.distplot(RJ['peso'], label='peso')
