# %%
import pandas as pd

# %%
import seaborn as sns

# %%
dados = pd.read_csv(r'C:\Users\BSSRIO_DIR\Documents\Olimpiadas.csv')

# %%
rio = dados['cidade_sede'] == 'Rio de Janeiro'

# %%
RJ = dados[rio]

# %%
filtro1 = RJ['esporte'] == 'Gymnastics'

# %%
gym = RJ[filtro1]

# %%
gym['peso'].hist()
# Out:
# <AxesSubplot:>

# %%
filtro2 = RJ['esporte'] == 'Handball'

# %%
hnd = RJ[filtro2]

# %%
hnd['peso'].hist()
# Out:
# <AxesSubplot:>

# %%
RJ['medalha'][268746]
# Out:
# 3.0

# %%
RJ= RJ.fillna('Lata', inplace = False)

# %%
def classificacao (medalha):
    if medalha == 'Gold':
        return 1
    elif medalha == 'Silver':
        return 2
    elif medalha == 'Bronze':
        return 3

# %%
RJ['medalha'] = RJ['medalha'].map(classificacao)

# %%
dados['medalha'] = dados['medalha'].map(classificacao)

# %%
fig = sns.displot(bra, x='medalha', hue = "esporte")

# %%
sns.pairplot(dados, hue='esporte', vars=['medalha','ano'])

# %%
bra['medalha'].value_counts()

# %%
filtro5 = RJ['delegacao'] == 'BRA'
bra = RJ[filtro5]
